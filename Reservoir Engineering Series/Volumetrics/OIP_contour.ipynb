# %%
import pandas as pd
import matplotlib.tri as tri
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
from experimentation import td_triangulation
from experimentation import trid_triangulation
from experimentation import hm_overlay
from experimentation import anotation

# Load data
welldat = pd.read_csv('data\Example of Well-Data 1.1.csv')
x, y, depth = welldat['x'], welldat['y'], welldat['DEPTH']
z = depth

# %%
#plot and compute triangulation contour
td_plotting = td_triangulation.plot_contour(welldat, save_path="output/2D_contour_plot.png")
# Out:
# Plot saved to output/2D_contour_plot.png

# %%
trid_plotting = trid_triangulation.plot_3d_contour(welldat, save_path="output/3D_contour_plot.png")
# Out:
# 3D plot saved to output/3D_contour_plot.png

# %%
overlay = hm_overlay.plot_contour_with_heatmap(welldat, save_path="output/overlay_heatmap.png")
# Out:
# Heatmap overlay saved to output/overlay_heatmap.png

# %%
anotation_plot = anotation.plot_contour_with_annotations(welldat, save_path="output/anotation_image.png")
# Out:
# Annotated plot saved to output/anotation_image.png
