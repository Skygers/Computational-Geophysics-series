# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
# sys.path.append("Reservoir Engineering Series")
from function.z_corellation_function.dranchuk_kaseem import DAK
from function.z_corellation_function.hall_yarborough import hall_yarborough
from function.z_corellation_function.kareem import kareem
from function.z_corellation_function.londono import londono
from function.z_corellation_function.value_new import *

# %%
calculation = calc_z(sg=0.7, T=75, zmodel="kareem", P=2010, ps_props=True)
calculation
# Out:
# {'z': 0.7305674580235196,
#  'Tpc': 371.4335560823552,
#  'Ppc': 660.6569792741872,
#  'J': 0.56221847,
#  'K': 14.450840999999999,
#  'Tr': 1.4394768357478496,
#  'Pr': 3.0646766226921294}

# %%
result, fig, ax =quickstart(zmodel='londono', prmin=3, prmax=12, figsize= (8, 4),
                            title_underline_loc=0.91, disable_tr_annotation=True,
                            title_bold='Londono Model', title_plain=' Compressibility Factor')
